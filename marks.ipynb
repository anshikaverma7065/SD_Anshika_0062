# %%
l=[1,345,45,"sudh",True,5+7j,345.56]

# %%
l[5].real
# Out:
# 5.0

# %%
l[-1:-5:-2]
# Out:
# [345.56, True]

# %%
l[-1]
# Out:
# 345.56

# %%
l[::-1]
# Out:
# [345.56, (5+7j), True, 'sudh', 45, 345, 1]

# %%
l
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345.56]

# %%
s="anshika"

# %%
l+s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_749/1140923193.py in <cell line: 0>()
# ----> 1 l+s
#
# TypeError: can only concatenate list (not "str") to list

# %%
list(s)+l
# Out:
# ['a', 'n', 's', 'h', 'i', 'k', 'a', 1, 345, 45, 'sudh', True, (5+7j), 345.56]

# %%
l+11
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_749/2305913786.py in <cell line: 0>()
# ----> 1 l+11
#
# TypeError: can only concatenate list (not "int") to list

# %%
l1 =[3,4,5]

# %%
l+l1
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345.56, 3, 4, 5]

# %%
l1*3
# Out:
# [3, 4, 5, 3, 4, 5, 3, 4, 5]

# %%
len(l)
# Out:
# 7

# %%
l.append(5)

# %%
l
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345.56, 5]

# %%
l.append(s)

# %%
l
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345.56, 5, 'anshika']

# %%
l.append(l1)

# %%
l
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345.56, 5, 'anshika', [3, 4, 5]]

# %%
l[-1][1]
# Out:
# 4

# %%
l.extend(4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_749/2311825727.py in <cell line: 0>()
# ----> 1 l.extend(4)
#
# TypeError: 'int' object is not iterable

# %%
l.extend("sudh")

# %%
l
# Out:
# [1,
#  345,
#  45,
#  'sudh',
#  True,
#  (5+7j),
#  345.56,
#  5,
#  'anshika',
#  [3, 4, 5],
#  's',
#  'u',
#  'd',
#  'h']

# %%
l.extend([3,4,5])

# %%
l
# Out:
# [1,
#  345,
#  45,
#  'sudh',
#  True,
#  (5+7j),
#  345.56,
#  5,
#  'anshika',
#  [3, 4, 5],
#  's',
#  'u',
#  'd',
#  'h',
#  3,
#  4,
#  5]

# %%
l1.insert(1,"sudh")

# %%
l1
# Out:
# [3, 'sudh', 4, 5]

# %%
l1.insert(2,[2,3,4])

# %%
l1
# Out:
# [45, 'sudh', [2, 3, 4], [2, 3, 4], 45]

# %%
l1.insert(-1,45)

# %%
l1
# Out:
# [3, 'sudh', [2, 3, 4], [2, 3, 4], 4, 45, 5]

# %%
l1.insert(0,45)

# %%
l1
# Out:
# [45, 3, 'sudh', [2, 3, 4], [2, 3, 4], 4, 45, 5]

# %%
l1.pop(3)
# Out:
# [2, 3, 4]

# %%
l1
# Out:
# [45, 'sudh', [2, 3, 4], 45]

# %%
l1.remove(234)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_749/2189347925.py in <cell line: 0>()
# ----> 1 l1.remove(234)
#
# ValueError: list.remove(x): x not in list

# %%
l1.append(4)

# %%
l1
# Out:
# [45, 'sudh', [2, 3, 4], 45, 4]

# %%
l1.remove(4)

# %%
l1
# Out:
# [45, 'sudh', [2, 3, 4], 45]

# %%
l1.pop(2)
# Out:
# [2, 3, 4]

# %%
l1
# Out:
# [45, 'sudh', 45]

# %%
l1.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_749/2406146923.py in <cell line: 0>()
# ----> 1 l1.sort()
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
l2=[45,23,90,0,3,4,5,6,7,8,9]

# %%
l2.sort()

# %%
l2
# Out:
# [0, 3, 4, 5, 6, 7, 8, 9, 23, 45, 90]

# %%
l4=["sudh","rohit","kumar","data science"]

# %%
l4.count("sudh")
# Out:
# 1

# %%
s="sudh"

# %%
l5=[23,56,32,45]

# %%
l5[0]=30

# %%
l5
# Out:
# [30, 56, 32, 45]

# %%
s
# Out:
# 'sudh'

# %%
s.replace('s','a')
# Out:
# 'audh'

# %%
s
# Out:
# 'sudh'

# %%
t=(2,3,4,5,"sudh",45.56,False,45+457j,[3,4,5])

# %%
t
# Out:
# (2, 3, 4, 5, 'sudh', 45.56, False, (45+457j), [3, 4, 5])

# %%
type(t)
# Out:
# tuple

# %%
len(t)
# Out:
# 9

# %%
t[0]
# Out:
# 2

# %%
t[-1]
# Out:
# [3, 4, 5]

# %%
t*3
# Out:
# (2,
#  3,
#  4,
#  5,
#  'sudh',
#  45.56,
#  False,
#  (45+457j),
#  [3, 4, 5],
#  2,
#  3,
#  4,
#  5,
#  'sudh',
#  45.56,
#  False,
#  (45+457j),
#  [3, 4, 5],
#  2,
#  3,
#  4,
#  5,
#  'sudh',
#  45.56,
#  False,
#  (45+457j),
#  [3, 4, 5])

# %%
s1={}

# %%
type(s1)
# Out:
# dict

# %%
s2={2,3,4,55,6}

# %%
type(s2)
# Out:
# set

# %%
s3={324,456,456,"sudh",45+45j,34.465,(3,4,5)}

# %%
s3
# Out:
# {(3, 4, 5), (45+45j), 324, 34.465, 456, 'sudh'}

# %%
s4={2,3,4,5,6,2,2,3,4,5,2,3,1,2,3,4,5,6,1,2,2,3,'Sudh','sudh'}

# %%
s4
# Out:
# {1, 2, 3, 4, 5, 6, 'Sudh', 'sudh'}

# %%
l6={2,3,4,5,6,2,2,3,4,5,2,3,1,2,3,4,5,6,1,2,2,3,'Sudh','sudh'}

# %%
l6
# Out:
# {1, 2, 3, 4, 5, 6, 'Sudh', 'sudh'}

# %%
s5={234,45,23,12,567,45,2,789,234,"abc",456,342,23}

# %%
s5.add(4)

# %%
s5
# Out:
# {12, 2, 23, 234, 342, 4, 45, 456, 567, 789, 'abc'}

# %%
s5.remove(2)

# %%
s5
# Out:
# {12, 23, 234, 342, 4, 45, 456, 567, 789, 'abc'}

# %%
l4
# Out:
# ['sudh', 'rohit', 'kumar', 'data science']

# %%
d={}

# %%
type(d)
# Out:
# dict

# %%
d1={'key':"sudh"}

# %%
d1
# Out:
# {'key': 'sudh'}

# %%
d2={'name':"sudhanshu","email":"ss@gmail.com","number":334534}

# %%
d2
# Out:
# {'name': 'sudhanshu', 'email': 'ss@gmail.com', 'number': 334534}

# %%
d3={234:"sudh",'_wer':"kumar",True:24234}

# %%
d3[234]
# Out:
# 'sudh'

# %%
d3[True]
# Out:
# 24234

# %%
d3[1]
# Out:
# 24234

# %%
marks=int(input("enter your marks"))
if marks>=80:
 print("you will be part of A0 batch")
elif marks>=60 and marks< 80:
 print("you will be a part of A1 batch")
elif marks>=40 and marks<60 :
  print("you will be a part of A2 batch")
else:
  print("you will be a part of A3 batch")
# Out:
# enter your marks95
# you will be part of A0 batch

# %%
name= str(input("enter your name"))
course =str(input("enter your course"))
rollno=int(input("enter yor roll number"))
branch=str(input("enter your branch"))
marks=int(input("enter your marks"))
if marks>=80:
 print("you will be part of A0 batch")
elif marks>=60 and marks< 80:
 print("you will be a part of A1 batch")
elif marks>=40 and marks<60 :
  print("you will be a part of A2 batch")
else:
  print("you will be a part of A3 batch")
# Out:
# enter your nameAnshika
# enter your courseBtech
# enter yor roll number62
# enter your branchCSE
# enter your marks95
# you will be part of A0 batch
