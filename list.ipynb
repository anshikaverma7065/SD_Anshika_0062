# %%
nums=[1,2,3,4]

# %%
nums[0]
# Out:
# 1

# %%
nums[4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_697/2255194133.py in <cell line: 0>()
# ----> 1 nums[4]
#
# IndexError: list index out of range

# %%
l=[1,3545,45,"sudh",True,5+7j,345.76]

# %%
l[5].real
# Out:
# 5.0

# %%
l[::2]
# Out:
# [1, 45, True, 345.76]

# %%
l[0:5:2]
# Out:
# [1, 45, True]

# %%
l[0:3]
# Out:
# [1, 3545, 45]

# %%
l[-1]
# Out:
# 345.76

# %%
l[-1:-5:-2]
# Out:
# [345.76, True]

# %%
l[1:6:-2]
# Out:
# []

# %%
l[-1::-6]
# Out:
# [345.76, 1]

# %%
l.append(34)

# %%
l
# Out:
# [1, 3545, 45, 'sudh', True, (5+7j), 345.76, 34]

# %%
l.pop()
# Out:
# 34

# %%
s="hello"

# %%
l+s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_697/1140923193.py in <cell line: 0>()
# ----> 1 l+s
#
# TypeError: can only concatenate list (not "str") to list

# %%
list(s)+l
# Out:
# ['h', 'e', 'l', 'l', 'o', 1, 3545, 45, 'sudh', True, (5+7j), 345.76]

# %%
l1=[23,"hey",45.67,123]

# %%
l1.append(29)

# %%
l1
# Out:
# [23, 'hey', 45.67, 123, 29]

# %%
l1.pop()
# Out:
# 29

# %%
l1
# Out:
# [23, 'hey', 45.67, 123]

# %%
l[3][0:2]
# Out:
# 'su'

# %%
str(l[4])[0:2]
# Out:
# 'Tr'

# %%
l.insert(2,34)

# %%
l
# Out:
# [1, 3545, 34, 45, 'sudh', True, (5+7j), 345.76]

# %%
l.remove(34)

# %%
l
# Out:
# [1, 3545, 45, 'sudh', True, (5+7j), 345.76]

# %%
name= input("Enter your name : ")
# Out:
# Enter your name : Anshika

# %%
age=int(input("Enter your age: "))
# Out:
# Enter your age: 18

# %%
print("Name:",name)
# Out:
# Name: Anshika

# %%
print("Age : ",age)
# Out:
# Age :  18

# %%
x="10"

# %%
y=int(x)

# %%
y
# Out:
# 10

# %%
x="3.14"

# %%
y=float(x)

# %%
y
# Out:
# 3.14

# %%
x=25

# %%
y=str(x)

# %%
y
# Out:
# '25'
