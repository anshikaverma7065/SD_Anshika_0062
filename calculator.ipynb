# %%
def calc(a,b,p):
   if(p=="+"):
     print(a+b)
   elif(p=="-"):
    print(a-b)
   elif(p=="/"):
    print(a/b)
   return "done"
n1=int(input("enter num1"))
n2=int(input("enter num2"))
op=(input("enter opt"))
calc(n1,n2,op)
# Out:
# enter num145
# enter num25
# enter opt/
# 9.0
# 'done'
